# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlokVaibhav/AI_for_Analog_Design/blob/main/NGspice_in_colab_via_Pyspice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! python --version    # Pyspice works with python  3.9 or lower
# !wget https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/requirements.txt    # fetch the package requirements file
# !wget https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/pyspice_trial.py   # fetch the python file
# Out:
# Python 3.11.11
# --2025-10-18 04:46:58--  https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/requirements.txt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘requirements.txt.1’
#
# requirements.txt.1      [ <=>                ] 180.30K  --.-KB/s    in 0.1s
#
# 2025-10-18 04:46:58 (1.84 MB/s) - ‘requirements.txt.1’ saved [184630]
#
# --2025-10-18 04:46:58--  https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/pyspice_trial.py
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘pyspice_trial.py.1’
#
# pyspice_trial.py.1      [ <=>                ] 185.86K  --.-KB/s    in 0.07s
#
# ...

# %%
# Source: (S1) https://stackoverflow.com/questions/72133319/oserror-cannot-load-library-libngspice-so-libngspice-so-on-google-colab
# First answer
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
# We need to work with an older python version, 3.9 so we are creating
# a new conda environment with python 3.9 installed
# it is named unironically as env_name

# Source:(S2) https://stackoverflow.com/questions/76442909/downgrade-python-3-10-to-3-9-in-google-colab
# First answer
! conda create -n env_name python=3.9
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/env_name
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       hda65f42_8         254 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     ld_impl_linux-64-2.44      |       ha97dd6f_2         730 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.5.2               |       h9ec8514_0          56 KB  conda-forge
# ...

# %%
! source activate env_name; python --version   # Python 3.9
# Out:
# Python 3.9.23

# %%
# Installing ngspice [S1] but inside the new environment [S2]
# !source activate env_name; conda install -c conda-forge ngspice-exe
# !source activate env_name; conda install -c conda-forge ngspice
# !source activate env_name; conda install -c conda-forge ngspice-lib
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/env_name
#
#   added / updated specs:
#     - ngspice-exe
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gettext-0.25.1             |       h3f43e3d_1         529 KB  conda-forge
#     gettext-tools-0.25.1       |       h3f43e3d_1         3.5 MB  conda-forge
#     libasprintf-0.25.1         |       h3f43e3d_1          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h3f43e3d_1          34 KB  conda-forge
#     libgettextpo-0.25.1        |       h3f43e3d_1         184 KB  conda-forge
# ...

# %%
# Installing the required python packages [S2]
! source activate env_name; python --version; pip -V; pip install -r requirements.txt
# Out:
# Python 3.9.23
# pip 25.2 from /usr/local/envs/env_name/lib/python3.9/site-packages/pip (python 3.9)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 134.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 111.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 99.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 113.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 23.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 65.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [pyspice]
# ...

# %%
# now inside my_env, we will run a python file (S3: https://pyspice.fabrice-salvaire.fr/releases/v1.5/examples/filter/low-pass-rc-filter.html)
# i have simplified the code to remove some errors
# %matplotlib inline
# !source activate env_name; MPLBACKEND=Agg python pyspice_trial.py
from IPython.display import Image
Image("output_plot.png")
# The spice simulator works correctly and you can see the bode plot for the RC filter
# Out:
# 2025-10-18 04:47:51,711 - PySpice.Spice.Netlist.Node.__init__ - WARNING - Node name 'in' is a Python keyword
# Break frequency = 159.2 Hz
# 2025-10-18 04:47:51,843 - PySpice.Spice.NgSpice.Shared.NgSpiceShared._init_ngspice - WARNING - Unsupported Ngspice version 41
# out
# 2025-10-18 04:47:51,857 - PySpice.Probe.WaveForm.WaveForm.__array_ufunc__ - WARNING - Should be unit less
