# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlokVaibhav/AI_for_Analog_Design/blob/main/NGspice_in_colab_skywater_pdk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! python --version    # Pyspice works with python  3.9 or lower
# !wget https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/SPICE.cir    # fetch the spice.cir file
# !wget https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/spice.py   # fetch the python file
# Out:
# Python 3.12.12
# --2025-10-18 11:57:17--  https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/SPICE.cir
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SPICE.cir.1’
#
# SPICE.cir.1             [ <=>                ] 182.34K  --.-KB/s    in 0.02s
#
# 2025-10-18 11:57:18 (7.13 MB/s) - ‘SPICE.cir.1’ saved [186714]
#
# --2025-10-18 11:57:18--  https://github.com/ShlokVaibhav/AI_for_Analog_Design/blob/main/spice.py
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘spice.py’
#
# spice.py                [ <=>                ] 180.55K  --.-KB/s    in 0.02s
#
# 2025-10-18 11:57:18 (7.96 MB/s) - ‘spice.py’ saved [184880]

# %%
# Source: (S1) https://stackoverflow.com/questions/72133319/oserror-cannot-load-library-libngspice-so-libngspice-so-on-google-colab
# First answer
# !pip install -q condacolab
# !pip install matplotlib
# !pip install numpy
import condacolab
condacolab.install()

# copying skywater pdk files
# !mkdir ./sky130
# !cd ./sky130
# !git clone https://github.com/google/skywater-pdk-libs-sky130_fd_pr.git
# Out:
# ...
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:20
# 🔁 Restarting kernel...

# %%
# Installing ngspice [S1] but inside the new environment [S2]
# !conda install -c conda-forge ngspice-exe
# !conda install -c conda-forge ngspice
# !conda install -c conda-forge ngspice-lib
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ngspice-exe
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     gettext-0.25.1             |       h5888daf_0         525 KB  conda-forge
#     gettext-tools-0.25.1       |       h5888daf_0         3.5 MB  conda-forge
#     libasprintf-0.25.1         |       h8e693c7_0          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h8e693c7_0          34 KB  conda-forge
#     libgettextpo-0.25.1        |       h5888daf_0         174 KB  conda-forge
# ...

# %%
import os

path = "./skywater-pdk-libs-sky130_fd_pr/models/sky130.lib.spice"

if os.path.exists(path):
    print("Path exists.")
else:
    print("Path does not exist.")
# Out:
# Path exists.

# %%
text = """* NMOS Transfer and Output Characteristics
* Generated 10-Oct-2021 10:31:26
* Include SkyWater sky130 device models
.lib "./skywater-pdk-libs-sky130_fd_pr/models/sky130.lib.spice" tt
.option scale=1e-6
xm1	d1 g1 0 0	sky130_fd_pr__nfet_01v8_lvt w=1 l=0.5
vgs	g1 0		dc=0.9
vds	d1 0		dc=0.9
.control
dc vgs 0 1.8 0.01
wrdata nmos_01v8_transfer_tt.dat -i(vds)
dc vds 0 1.8 0.01
wrdata nmos_01v8_output_tt.dat -i(vds)
.endc
.end
"""
# Save to file
with open("NMOS_test.cir", "w") as f:
    f.write(text)

# Verify
# !cat NMOS_test.txt
# Out:
# cat: NMOS_test.txt: No such file or directory

# %%
# os.system directly executes the spice command, check out.txt
# %matplotlib inline
import math
import numpy as np

import matplotlib.pyplot as plt

import os
# Path to the file
file_path = "out_NMOS3.txt"

# Check if file exists, then delete
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} deleted successfully.")
else:
    print(f"{file_path} does not exist.")
# Out:
# out_NMOS3.txt deleted successfully.

# %%
os.system("ngspice < NMOS_test.cir > out_NMOS3.txt 2>&1")
# Out:
# 256

# %%
with open('out_NMOS3.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Error in line   include "sky130_fd_pr__esd_nfet_05v0_nvt.pm3"
#     Not enough parameters
#
# ERROR: fatal error in ngspice, exit(1)
#
# Note: No compatibility mode selected!
